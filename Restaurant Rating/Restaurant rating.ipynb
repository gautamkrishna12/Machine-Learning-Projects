# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Dataset .csv')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# LEVEL 1

# %% [markdown]
# Task 1

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (9542, 21)

# %%
sns.histplot(df['Aggregate rating'],bins=40)
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Count'>

# %%
df['Rating text'].value_counts().plot(kind='pie',autopct='%1.0f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.boxplot(x='Rating text',y='Aggregate rating',data=df,hue='Rating text',palette='coolwarm')
# Out:
# <Axes: xlabel='Rating text', ylabel='Aggregate rating'>

# %%
sns.jointplot(x='Aggregate rating',y='Votes',data=df,hue='Rating text')

# %%
df['Rating text'].value_counts()
# Out:
# Rating text
# Average      3734
# Not rated    2148
# Good         2096
# Very Good    1078
# Excellent     300
# Poor          186
# Name: count, dtype: int64

# %% [markdown]
# Task 2

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.542000e+03   9542.000000  9542.000000  9542.000000
# mean    9.043301e+06     18.179208    64.274997    25.848532
# std     8.791967e+06     56.451600    41.197602    11.010094
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019312e+05      1.000000    77.081565    28.478658
# 50%     6.002726e+06      1.000000    77.192031    28.570444
# 75%     1.835260e+07      1.000000    77.282043    28.642711
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9542.000000  9542.000000       9542.000000   9542.000000
# mean            1200.326137     1.804968          2.665238    156.772060
# std            16128.743876     0.905563          1.516588    430.203324
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df['Country Code'].unique()
# Out:
# array([162,  30, 216,  14,  37, 184, 214,   1,  94, 148, 215, 166, 189,
#        191, 208], dtype=int64)

# %%
sns.barplot(df['Country Code'].value_counts())
# Out:
# <Axes: xlabel='Country Code', ylabel='count'>

# %%
df['City'].nunique()
# Out:
# 140

# %%
Top10_city=df['City'].value_counts().head(10)

# %%
Top10_city
# Out:
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Ahmedabad         21
# Guwahati          21
# Amritsar          21
# Bhubaneshwar      21
# Lucknow           21
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(Top10_city)
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %%
df['Cuisines'].nunique()
# Out:
# 1825

# %%
Top10_Cuisines=df['Cuisines'].value_counts().head(5)

# %%
plt.figure(figsize=(12,6))
sns.barplot(Top10_Cuisines)
# Out:
# <Axes: xlabel='Cuisines', ylabel='count'>

# %%
#Top 5 City with heighest number of restaurants
df['City'].value_counts().head(5)
# Out:
# City
# New Delhi    5473
# Gurgaon      1118
# Noida        1080
# Faridabad     251
# Ghaziabad      25
# Name: count, dtype: int64

# %%
#Top 5 Cuisines 
df['Cuisines'].value_counts().head(5)
# Out:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Fast Food                354
# North Indian, Mughlai    334
# Name: count, dtype: int64

# %% [markdown]
# Task 3 :Geospatial Analysis

# %%
df['Country Code'].unique()
# Out:
# array([162,  30, 216,  14,  37, 184, 214,   1,  94, 148, 215, 166, 189,
#        191, 208], dtype=int64)

# %%
plt.figure(figsize=(6,5))
df['Country Code'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Country Code'>

# %%
plt.figure(figsize=(4,3))
correlation = df[['Latitude', 'Longitude','Country Code','Aggregate rating']].corr()
sns.heatmap(correlation,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
corr_lat_rating = correlation.loc['Latitude', 'Aggregate rating']
print(f"* Correlation between Latitude and Aggregate rating: {corr_lat_rating}")

corr_long_rating = correlation.loc['Longitude', 'Aggregate rating']
print(f"\n* Correlation between Longitude and Aggregate rating: {corr_long_rating}")

corr_country_code= correlation.loc['Country Code','Aggregate rating']
print(f"\n* Correlation between Country code and Aggregate rating: {corr_country_code}")
# Out:
# * Correlation between Latitude and Aggregate rating: 0.00019656901824268181
#
# * Correlation between Longitude and Aggregate rating: -0.11473320326490552
#
# * Correlation between Country code and Aggregate rating: 0.28129524976374437

# %% [markdown]
# Level 2
# Task 1: Table Booking and Online Delivery

# %%
#percentage of restaurants that offer table booking and online delivery

resturants=len(df[(df['Has Table booking']=='Yes') & (df['Has Online delivery']=='Yes')])*100/len(df)
print(f"* Percentage of restaurants that offer table booking and online delivery : {resturants:.2f} %")
# Out:
# * Percentage of restaurants that offer table booking and online delivery : 4.56 %

# %%
#Ratings of restaurants with table booking and those without
plt.figure(figsize=(6,4))
plt.subplot(121,)
df[df['Has Table booking']=='Yes']['Aggregate rating'].plot(kind='hist',bins=30)
plt.title('With Table Booking')
plt.subplot(122)
plt.title('without Table Booking')
df[df['Has Table booking']=='No']['Aggregate rating'].plot(kind='hist',bins=30)
plt.tight_layout()

# %%
avg1=np.mean(df[df['Has Table booking']=='No']['Aggregate rating'])
print(f'* Average rating for resturants without table booking : {avg1:.2f}')

avg2=np.mean(df[df['Has Table booking']=='Yes']['Aggregate rating'])
print(f'\n* Average rating for resturants with table booking : {avg2:.2f}')
# Out:
# * Average rating for resturants without table booking : 2.56
#
# * Average rating for resturants with table booking : 3.44

# %%
df.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
#
# [1 rows x 21 columns]

# %%
plt.figure(figsize=(4,3))
sns.barplot(df['Price range'].value_counts())
# Out:
# <Axes: xlabel='Price range', ylabel='count'>

# %%
#Availability of online delivery among restaurants with different price ranges.
print(df[df['Has Online delivery']=='Yes']['Price range'].value_counts().sort_index())

plt.figure(figsize=(4,3))
sns.barplot(df[df['Has Online delivery']=='Yes']['Price range'].value_counts())
# Out:
# Price range
# 1     701
# 2    1286
# 3     411
# 4      53
# Name: count, dtype: int64
# <Axes: xlabel='Price range', ylabel='count'>

# %% [markdown]
# Task 2: Price Range Analysis

# %%
#Most common price range
df['Price range'].value_counts().head(1)
# Out:
# Price range
# 1    4438
# Name: count, dtype: int64

# %%
#Average rating for each price range.
print("Average rating for each price range.\n")
Rating_on_price=df[['Aggregate rating','Price range']].groupby("Price range").mean()
Rating_on_price
# Out:
# Average rating for each price range.
#              Aggregate rating
# Price range
# 1                    1.997476
# 2                    2.941054
# 3                    3.682633
# 4                    3.817918

# %%
max_avg_rating=round(Rating_on_price['Aggregate rating'].max(),1)
color=df[df['Aggregate rating']==max_avg_rating]['Rating color'].iloc[0]
print(f"THe maximum average rating : {max_avg_rating}\n\nRating color : {color}.")
# Out:
# THe maximum average rating : 3.8
#
# Rating color : Yellow.

# %% [markdown]
# Task 3:Feature Engineering

# %%
df['Has Table booking']=df['Has Table booking'].apply(lambda s: 1 if s=='Yes' else 0)

# %%
df['Has Online delivery']=df['Has Online delivery'].apply(lambda s: 1 if s=='Yes' else 0)

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# Level 3
# Task 1:Predictive Modeling
